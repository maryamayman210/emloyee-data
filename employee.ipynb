# %%
import pandas as pd

# %%
employee=pd.read_excel("Employees (3).xlsx")

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1378 entries, 0 to 1377
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   No              1378 non-null   int64
#  1   First Name      1378 non-null   object
#  2   Last Name       1378 non-null   object
#  3   Gender          1378 non-null   object
#  4   Start Date      1378 non-null   int64
#  5   Years           1378 non-null   int64
#  6   Department      1378 non-null   object
#  7   Country         1378 non-null   object
#  8   Center          1378 non-null   object
#  9   Monthly Salary  1378 non-null   int64
#  10  Annual Salary   1378 non-null   int64
#  11  Job Rate        1378 non-null   float64
#  12  Sick Leaves     1378 non-null   int64
#  13  Unpaid Leaves   1378 non-null   int64
#  14  Overtime Hours  1378 non-null   int64
# dtypes: float64(1), int64(8), object(6)
# memory usage: 161.6+ KB

# %%
employee.head()
# Out:
#    No First Name Last Name  Gender  Start Date  Years          Department  \
# 0   1     Ghadir     Hmshw    Male       43194      5     Quality Control
# 1   2       Omar    Hishan    Male       43972      3     Quality Control
# 2   3      Ailya    Sharaf  Female       43006      6  Major Mfg Projects
# 3   4       Lwiy     Qbany    Male       43326      5       Manufacturing
# 4   5      Ahmad     Bikri    Male       43901      4       Manufacturing
#
#                 Country Center  Monthly Salary  Annual Salary  Job Rate  \
# 0                 Egypt   West            1560          18720       3.0
# 1          Saudi Arabia   West            3247          38964       1.0
# 2          Saudi Arabia   West            2506          30072       2.0
# 3  United Arab Emirates   Main            1828          21936       3.0
# 4                 Egypt   Main             970          11640       5.0
#
#    Sick Leaves  Unpaid Leaves  Overtime Hours
# ...

# %%
employee.tail()
# Out:
#        No   First Name Last Name Gender  Start Date  Years  \
# 1373  685         Sari     Hanna   Male       43977      0
# 1374  686      Eubayda      Kayd   Male       43985      0
# 1375  687       Khalil    Alkalu   Male       42927      3
# 1376  688      Muhamad    Shrbjy   Male       43250      2
# 1377  689  Abd Albasit   AlAhmar   Male       44048      0
#
#                   Department               Country Center  Monthly Salary  \
# 1373               Marketing               Lebanon  South            1452
# 1374  Facilities/Engineering                 Egypt  North            3237
# 1375  Facilities/Engineering                 Egypt  North            2819
# 1376                Creative                 Egypt  North            2069
# 1377                      IT  United Arab Emirates  North            2606
#
#       Annual Salary  Job Rate  Sick Leaves  Unpaid Leaves  Overtime Hours
# 1373          17424       2.0            0              3               1
# ...

# %%
employee.isnull()
# Out:
#          No  First Name  Last Name  Gender  Start Date  Years  Department  \
# 0     False       False      False   False       False  False       False
# 1     False       False      False   False       False  False       False
# 2     False       False      False   False       False  False       False
# 3     False       False      False   False       False  False       False
# 4     False       False      False   False       False  False       False
# ...     ...         ...        ...     ...         ...    ...         ...
# 1373  False       False      False   False       False  False       False
# 1374  False       False      False   False       False  False       False
# 1375  False       False      False   False       False  False       False
# 1376  False       False      False   False       False  False       False
# 1377  False       False      False   False       False  False       False
#
#       Country  Center  Monthly Salary  Annual Salary  Job Rate  Sick Leaves  \
# ...

# %%
employee.dtypes
# Out:
# No                  int64
# First Name         object
# Last Name          object
# Gender             object
# Start Date          int64
# Years               int64
# Department         object
# Country            object
# Center             object
# Monthly Salary      int64
# Annual Salary       int64
# Job Rate          float64
# Sick Leaves         int64
# Unpaid Leaves       int64
# Overtime Hours      int64
# dtype: object

# %%
employee.select_dtypes("int")
# Out:
#        No  Start Date  Years  Monthly Salary  Annual Salary  Sick Leaves  \
# 0       1       43194      5            1560          18720            1
# 1       2       43972      3            3247          38964            0
# 2       3       43006      6            2506          30072            0
# 3       4       43326      5            1828          21936            0
# 4       5       43901      4             970          11640            0
# ...   ...         ...    ...             ...            ...          ...
# 1373  685       43977      0            1452          17424            0
# 1374  686       43985      0            3237          38844            1
# 1375  687       42927      3            2819          33828            0
# 1376  688       43250      2            2069          24828            0
# 1377  689       44048      0            2606          31272            0
#
#       Unpaid Leaves  Overtime Hours
# 0                 0             183
# ...

# %%
employee.select_dtypes("object")
# Out:
#        First Name Last Name  Gender              Department  \
# 0          Ghadir     Hmshw    Male         Quality Control
# 1            Omar    Hishan    Male         Quality Control
# 2           Ailya    Sharaf  Female      Major Mfg Projects
# 3            Lwiy     Qbany    Male           Manufacturing
# 4           Ahmad     Bikri    Male           Manufacturing
# ...           ...       ...     ...                     ...
# 1373         Sari     Hanna    Male               Marketing
# 1374      Eubayda      Kayd    Male  Facilities/Engineering
# 1375       Khalil    Alkalu    Male  Facilities/Engineering
# 1376      Muhamad    Shrbjy    Male                Creative
# 1377  Abd Albasit   AlAhmar    Male                      IT
#
#                    Country Center
# 0                    Egypt   West
# 1             Saudi Arabia   West
# 2             Saudi Arabia   West
# 3     United Arab Emirates   Main
# 4                    Egypt   Main
# ...

# %%
employee.nunique()
# Out:
# No                689
# First Name        299
# Last Name         579
# Gender              2
# Start Date        539
# Years               9
# Department         20
# Country             5
# Center              5
# Monthly Salary    613
# Annual Salary     613
# Job Rate            5
# Sick Leaves         7
# Unpaid Leaves       7
# Overtime Hours     74
# dtype: int64

# %%
employee
# Out:
#        No   First Name Last Name  Gender  Start Date  Years  \
# 0       1       Ghadir     Hmshw    Male       43194      5
# 1       2         Omar    Hishan    Male       43972      3
# 2       3        Ailya    Sharaf  Female       43006      6
# 3       4         Lwiy     Qbany    Male       43326      5
# 4       5        Ahmad     Bikri    Male       43901      4
# ...   ...          ...       ...     ...         ...    ...
# 1373  685         Sari     Hanna    Male       43977      0
# 1374  686      Eubayda      Kayd    Male       43985      0
# 1375  687       Khalil    Alkalu    Male       42927      3
# 1376  688      Muhamad    Shrbjy    Male       43250      2
# 1377  689  Abd Albasit   AlAhmar    Male       44048      0
#
#                   Department               Country Center  Monthly Salary  \
# 0            Quality Control                 Egypt   West            1560
# 1            Quality Control          Saudi Arabia   West            3247
# ...

# %%
employee.Country.value_counts()
# Out:
# Country
# Egypt                   758
# United Arab Emirates    312
# Saudi Arabia            180
# Syria                   106
# Lebanon                  22
# Name: count, dtype: int64

# %%
employee.Country.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
employee["Years"].min()
# Out:
# 0

# %%
employee["Years"].max()
# Out:
# 8

# %%
employee["Years"].mean()
# Out:
# np.float64(3.0595065312046446)

# %%
employee["Years"].median()
# Out:
# 3.0

# %%
employee["Monthly Salary"].min()
# Out:
# 703

# %%
employee["Monthly Salary"].max()
# Out:
# 3450

# %%
employee["Monthly Salary"].mean()
# Out:
# np.float64(2068.201741654572)

# %%
employee["Monthly Salary"].median()
# Out:
# 2077.0

# %%
employee["Monthly Salary"].sort_values(ascending=False).head()
# Out:
# 1013    3450
# 324     3450
# 1036    3446
# 347     3446
# 1005    3443
# Name: Monthly Salary, dtype: int64

# %%
employee["Monthly Salary"].sort_values(ascending=False).tail()
# Out:
# 505     707
# 1304    705
# 615     705
# 913     703
# 224     703
# Name: Monthly Salary, dtype: int64
